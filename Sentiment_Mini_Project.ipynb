# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# Small sample sentiment dataset
texts = [
    "I love this product",
    "This is amazing",
    "I am very happy",
    "I hate this",
    "This is terrible",
    "I am very sad"
]

labels = [1, 1, 1, 0, 0, 0]  # 1 = Positive, 0 = Negative

# Vectorization
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texts)
print(X)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 17 stored elements and shape (6, 11)>
#   Coords	Values
#   (0, 5)	0.6520567053327203
#   (0, 9)	0.3868386046677293
#   (0, 6)	0.6520567053327203
#   (1, 9)	0.4169638817420929
#   (1, 4)	0.5763355687419489
#   (1, 1)	0.702835993333765
#   (2, 0)	0.5355058021985527
#   (2, 10)	0.5355058021985527
#   (2, 2)	0.6530444637414585
#   (3, 9)	0.5102266013323625
#   (3, 3)	0.8600400079605752
#   (4, 9)	0.4169638817420929
#   (4, 4)	0.5763355687419489
#   (4, 8)	0.702835993333765
#   (5, 0)	0.5355058021985527
#   (5, 10)	0.5355058021985527
#   (5, 7)	0.6530444637414585

# %%
import pandas as pd

X_dense = X.toarray()  # Convert sparse → dense (small datasets only!)
df = pd.DataFrame(X_dense, columns=vectorizer.get_feature_names_out())
print(df)
# Out:
#          am   amazing     happy     hate        is      love   product  \
# 0  0.000000  0.000000  0.000000  0.00000  0.000000  0.652057  0.652057
# 1  0.000000  0.702836  0.000000  0.00000  0.576336  0.000000  0.000000
# 2  0.535506  0.000000  0.653044  0.00000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.86004  0.000000  0.000000  0.000000
# 4  0.000000  0.000000  0.000000  0.00000  0.576336  0.000000  0.000000
# 5  0.535506  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
#
#         sad  terrible      this      very
# 0  0.000000  0.000000  0.386839  0.000000
# 1  0.000000  0.000000  0.416964  0.000000
# 2  0.000000  0.000000  0.000000  0.535506
# 3  0.000000  0.000000  0.510227  0.000000
# 4  0.000000  0.702836  0.416964  0.000000
# 5  0.653044  0.000000  0.000000  0.535506

# %%
# Train model
model = LogisticRegression()
model.fit(X, labels)

# Function for prediction
def predict_sentiment(text):
    vec = vectorizer.transform([text])
    prediction = model.predict(vec)[0]
    return "Positive" if prediction == 1 else "Negative"

# Test
print(predict_sentiment("I love this movie"))
print(predict_sentiment("I hate this film"))
# Out:
# Positive
# Negative
